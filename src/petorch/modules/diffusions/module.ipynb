# %%
from diffusers.models.unets.unet_2d_condition import UNet2DConditionOutput
from torch import nn
from enum import StrEnum
from transformers.modeling_outputs import BaseModelOutputWithPooling
from diffusers.models.autoencoders.vae import DiagonalGaussianDistribution
from lightning import LightningModule
from diffusers import StableDiffusionPipeline, AutoencoderKL, UNet2DConditionModel,  DDIMScheduler, DDPMScheduler
from transformers import CLIPTokenizer, CLIPTextModel, CLIPTokenizerFast, CLIPImageProcessor
from typing import Any, Self
from lightning.pytorch.utilities.types import STEP_OUTPUT, OptimizerLRScheduler
from pydantic import BaseModel, ConfigDict, model_validator
import torch
import torch.nn.functional as F



class SDTrainBatch(BaseModel):
    model_config = ConfigDict(arbitrary_types_allowed=True)

    input_ids: torch.Tensor
    images: torch.Tensor

    @model_validator(mode="after")
    def check_size(self)->Self:
        assert self.input_ids.size(0) == self.images.size(0)
        assert self.images.size(1) == 3
        return self


class PredictionType(StrEnum):
    EPSILON = "epsilon"
    SAMPLE = "sample"
    V_PREDICTION = "v_prediction"


class StableDiffusionModule(LightningModule):
    """
    Attributes:
        unet:
        vae:
        text_encoder:
        tokenizer:
         scheduler:

    """
    def __init__(self,
                pipeline: StableDiffusionPipeline | None = None,

                 *,
                 model_id: str | None = None,
                 vae: AutoencoderKL | None = None,
                 unet: UNet2DConditionModel | None = None,
                 text_encoder: CLIPTextModel | None = None,
                 tokenizer: CLIPTokenizer|CLIPTokenizerFast | None = None,
                 scheduler: DDIMScheduler|DDPMScheduler | None = None, # TODO: Make enum for typehint, hf so stupid
                 feature_extractor: CLIPImageProcessor|None=None,
                 **addition_kwargs
                 ):
        super().__init__()
        kwargs = dict(
            unet = unet,
            vae=vae,
            text_encoder = text_encoder,
            tokenizer=tokenizer,
            scheduler = scheduler,
            model_id=model_id,
            feature_extractor=feature_extractor,
        )
        # Delete all None values.
        del_k = []
        for k,v in kwargs.items():
            if v is None:
                del_k.append(k)
        for k in del_k:
            del kwargs[k]

        if pipeline is not None:
            assert isinstance(pipeline, StableDiffusionPipeline)
            if kwargs!={}:
                raise ValueError(f"All arguments must be None when `pipeline` is given. Got `{kwargs}.`")
        else:
            if kwargs.pop("model_id",None) is not None:
                pipeline = StableDiffusionPipeline.from_pretrained(model_id,**kwargs)
            else:
                # Does not require feature extractor.
                if "feature_extractor" not in kwargs:
                    kwargs["feature_extractor"] = None
                pipeline = StableDiffusionPipeline(**kwargs, requires_safety_checker=False, safety_checker=None, image_encoder= None)

        self.unet: UNet2DConditionModel = pipeline.unet
        self.vae: AutoencoderKL = pipeline.vae
        self.text_encoder: CLIPTextModel = pipeline.text_encoder
        self.tokenizer:CLIPTokenizer|CLIPTokenizerFast = pipeline.tokenizer
        self.scheduler:DDIMScheduler|DDPMScheduler = pipeline.scheduler
        self.pipeline = pipeline

        self.addition_kwargs = addition_kwargs

    @property
    def latents_values_scaling(self) -> float:
        """Default to 0.18215 and latents values should be multiplied after `vae.encode` and `divided` before `vae.decode`."""
        return self.vae.config.scaling_factor

    @property
    def latents_spatial_reduced_ratio(self) -> int:
        """The reduced ratio"""
        return 2 ** (len(self.vae.config.block_out_channels) - 1)

    def vae_encode(self, images: torch.Tensor)->torch.Tensor:
        latent_dist:DiagonalGaussianDistribution = self.vae.encode(images).latent_dist
        latents = latent_dist.sample()*self.latents_values_scaling
        return latents

    def vae_decode(self, latents: torch.Tensor)->torch.Tensor:
        return self.vae.decode(latents/self.latents_values_scaling).sample

    def loss_fn(self, prediction: torch.Tensor, target: torch.Tensor)->torch.Tensor:
        reduction = self.addition_kwargs.get("reduction","mean")
        return F.mse_loss(prediction, target,reduction=reduction)

    def training_step(self, batch: SDTrainBatch, batch_index:int  , **kwargs: Any) -> STEP_OUTPUT:

        latents = self.vae_encode(images:=batch.images)
        noises = torch.rand_like(latents)
        timesteps = torch.randint(0, self.scheduler.config.num_train_timesteps,(latents.size(0),))
        noisy_latents = self.scheduler.add_noise(latents, noises, timesteps)

        text_encoder_output: BaseModelOutputWithPooling = self.text_encoder(input_ids:=batch.input_ids)
        text_embeddings = text_encoder_output.last_hidden_state

        print(images.shape, noises.shape, timesteps.shape)
        unet_output:UNet2DConditionOutput = self.unet(noisy_latents, timesteps, text_embeddings)
        model_pred = unet_output.sample

        if (pred_type := self.scheduler.config.prediction_type) == PredictionType.EPSILON:
            target = noises
        elif pred_type == PredictionType.SAMPLE:
            target = images
        elif pred_type == PredictionType.V_PREDICTION:
            target = self.scheduler.get_velocity(latents, noises, timesteps)
        else:
            raise RuntimeError(f"The `prediction_type`=`{pred_type}` is not supported.")

        loss = self.loss_fn(model_pred, target)

        # self.log("train_loss", loss)

        return loss

    def validation_step(self, *args: Any, **kwargs: Any) -> STEP_OUTPUT:
        pass

    def configure_optimizers(self) -> OptimizerLRScheduler:
        return torch.optim.Adam(self.parameters())

# %%
from torchvision.transforms.v2 import Resize
from PIL import Image
out = Resize(256)(Image.new("RGB", (700, 700), color="red"))

# %%
a = lambda : 5

# %%
a(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a(5)
#
# TypeError: <lambda>() takes 0 positional arguments but 1 was given

# %%
from diffusers import DDPMScheduler
from lightning.pytorch.utilities.model_summary import ModelSummary

model_id = "stabilityai/stable-diffusion-2-1"

scheduler_subfolder = "scheduler"
module = StableDiffusionModule(model_id=model_id)
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
ModelSummary(module, max_depth=-1)
# Out:
#      | Name                                                                | Type                    | Params | Mode
# --------------------------------------------------------------------------------------------------------------------------
# 0    | unet                                                                | UNet2DConditionModel    | 865 M  | eval
# 1    | unet.conv_in                                                        | Conv2d                  | 11.8 K | eval
# 2    | unet.time_proj                                                      | Timesteps               | 0      | eval
# 3    | unet.time_embedding                                                 | TimestepEmbedding       | 2.1 M  | eval
# 4    | unet.time_embedding.linear_1                                        | Linear                  | 410 K  | eval
# 5    | unet.time_embedding.act                                             | SiLU                    | 0      | eval
# 6    | unet.time_embedding.linear_2                                        | Linear                  | 1.6 M  | eval
# 7    | unet.down_blocks                                                    | ModuleList              | 251 M  | eval
# 8    | unet.down_blocks.0                                                  | CrossAttnDownBlock2D    | 10.9 M | eval
# 9    | unet.down_blocks.0.attentions                                       | ModuleList              | 5.4 M  | eval
# 10   | unet.down_blocks.0.attentions.0                                     | Transformer2DModel      | 2.7 M  | eval
# 11   | unet.down_blocks.0.attentions.0.norm                                | GroupNorm               | 640    | eval
# 12   | unet.down_blocks.0.attentions.0.proj_in                             | Linear                  | 102 K  | eval
# 13   | unet.down_blocks.0.attentions.0.transformer_blocks                  | ModuleList              | 2.5 M  | eval
# 14   | unet.down_blocks.0.attentions.0.transformer_blocks.0                | BasicTransformerBlock   | 2.5 M  | eval
# 15   | unet.down_blocks.0.attentions.0.transformer_blocks.0.norm1          | LayerNorm               | 640    | eval
# 16   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn1          | Attention               | 409 K  | eval
# 17   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_q     | Linear                  | 102 K  | eval
# 18   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_k     | Linear                  | 102 K  | eval
# 19   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_v     | Linear                  | 102 K  | eval
# 20   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_out   | ModuleList              | 102 K  | eval
# 21   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_out.0 | Linear                  | 102 K  | eval
# 22   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_out.1 | Dropout                 | 0      | eval
# 23   | unet.down_blocks.0.attentions.0.transformer_blocks.0.norm2          | LayerNorm               | 640    | eval
# 24   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn2          | Attention               | 860 K  | eval
# 25   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_q     | Linear                  | 102 K  | eval
# 26   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_k     | Linear                  | 327 K  | eval
# 27   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_v     | Linear                  | 327 K  | eval
# 28   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_out   | ModuleList              | 102 K  | eval
# 29   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_out.0 | Linear                  | 102 K  | eval
# 30   | unet.down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_out.1 | Dropout                 | 0      | eval
# 31   | unet.down_blocks.0.attentions.0.transformer_blocks.0.norm3          | LayerNorm               | 640    | eval
# 32   | unet.down_blocks.0.attentions.0.transformer_blocks.0.ff             | FeedForward             | 1.2 M  | eval
# 33   | unet.down_blocks.0.attentions.0.transformer_blocks.0.ff.net         | ModuleList              | 1.2 M  | eval
# 34   | unet.down_blocks.0.attentions.0.transformer_blocks.0.ff.net.0       | GEGLU                   | 821 K  | eval
# 35   | unet.down_blocks.0.attentions.0.transformer_blocks.0.ff.net.0.proj  | Linear                  | 821 K  | eval
# 36   | unet.down_blocks.0.attentions.0.transformer_blocks.0.ff.net.1       | Dropout                 | 0      | eval
# 37   | unet.down_blocks.0.attentions.0.transformer_blocks.0.ff.net.2       | Linear                  | 409 K  | eval
# 38   | unet.down_blocks.0.attentions.0.proj_out                            | Linear                  | 102 K  | eval
# 39   | unet.down_blocks.0.attentions.1                                     | Transformer2DModel      | 2.7 M  | eval
# 40   | unet.down_blocks.0.attentions.1.norm                                | GroupNorm               | 640    | eval
# 41   | unet.down_blocks.0.attentions.1.proj_in                             | Linear                  | 102 K  | eval
# 42   | unet.down_blocks.0.attentions.1.transformer_blocks                  | ModuleList              | 2.5 M  | eval
# 43   | unet.down_blocks.0.attentions.1.transformer_blocks.0                | BasicTransformerBlock   | 2.5 M  | eval
# 44   | unet.down_blocks.0.attentions.1.transformer_blocks.0.norm1          | LayerNorm               | 640    | eval
# 45   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn1          | Attention               | 409 K  | eval
# 46   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_q     | Linear                  | 102 K  | eval
# 47   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_k     | Linear                  | 102 K  | eval
# 48   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_v     | Linear                  | 102 K  | eval
# 49   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_out   | ModuleList              | 102 K  | eval
# 50   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_out.0 | Linear                  | 102 K  | eval
# 51   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_out.1 | Dropout                 | 0      | eval
# 52   | unet.down_blocks.0.attentions.1.transformer_blocks.0.norm2          | LayerNorm               | 640    | eval
# 53   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn2          | Attention               | 860 K  | eval
# 54   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_q     | Linear                  | 102 K  | eval
# 55   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_k     | Linear                  | 327 K  | eval
# 56   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_v     | Linear                  | 327 K  | eval
# 57   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_out   | ModuleList              | 102 K  | eval
# 58   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_out.0 | Linear                  | 102 K  | eval
# 59   | unet.down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_out.1 | Dropout                 | 0      | eval
# 60   | unet.down_blocks.0.attentions.1.transformer_blocks.0.norm3          | LayerNorm               | 640    | eval
# 61   | unet.down_blocks.0.attentions.1.transformer_blocks.0.ff             | FeedForward             | 1.2 M  | eval
# 62   | unet.down_blocks.0.attentions.1.transformer_blocks.0.ff.net         | ModuleList              | 1.2 M  | eval
# 63   | unet.down_blocks.0.attentions.1.transformer_blocks.0.ff.net.0       | GEGLU                   | 821 K  | eval
# 64   | unet.down_blocks.0.attentions.1.transformer_blocks.0.ff.net.0.proj  | Linear                  | 821 K  | eval
# 65   | unet.down_blocks.0.attentions.1.transformer_blocks.0.ff.net.1       | Dropout                 | 0      | eval
# 66   | unet.down_blocks.0.attentions.1.transformer_blocks.0.ff.net.2       | Linear                  | 409 K  | eval
# 67   | unet.down_blocks.0.attentions.1.proj_out                            | Linear                  | 102 K  | eval
# 68   | unet.down_blocks.0.resnets                                          | ModuleList              | 4.5 M  | eval
# 69   | unet.down_blocks.0.resnets.0                                        | ResnetBlock2D           | 2.3 M  | eval
# 70   | unet.down_blocks.0.resnets.0.norm1                                  | GroupNorm               | 640    | eval
# 71   | unet.down_blocks.0.resnets.0.conv1                                  | Conv2d                  | 921 K  | eval
# 72   | unet.down_blocks.0.resnets.0.time_emb_proj                          | Linear                  | 409 K  | eval
# 73   | unet.down_blocks.0.resnets.0.norm2                                  | GroupNorm               | 640    | eval
# 74   | unet.down_blocks.0.resnets.0.dropout                                | Dropout                 | 0      | eval
# 75   | unet.down_blocks.0.resnets.0.conv2                                  | Conv2d                  | 921 K  | eval
# 76   | unet.down_blocks.0.resnets.0.nonlinearity                           | SiLU                    | 0      | eval
# 77   | unet.down_blocks.0.resnets.1                                        | ResnetBlock2D           | 2.3 M  | eval
# 78   | unet.down_blocks.0.resnets.1.norm1                                  | GroupNorm               | 640    | eval
# 79   | unet.down_blocks.0.resnets.1.conv1                                  | Conv2d                  | 921 K  | eval
# 80   | unet.down_blocks.0.resnets.1.time_emb_proj                          | Linear                  | 409 K  | eval
# 81   | unet.down_blocks.0.resnets.1.norm2                                  | GroupNorm               | 640    | eval
# 82   | unet.down_blocks.0.resnets.1.dropout                                | Dropout                 | 0      | eval
# 83   | unet.down_blocks.0.resnets.1.conv2                                  | Conv2d                  | 921 K  | eval
# 84   | unet.down_blocks.0.resnets.1.nonlinearity                           | SiLU                    | 0      | eval
# 85   | unet.down_blocks.0.downsamplers                                     | ModuleList              | 921 K  | eval
# 86   | unet.down_blocks.0.downsamplers.0                                   | Downsample2D            | 921 K  | eval
# 87   | unet.down_blocks.0.downsamplers.0.conv                              | Conv2d                  | 921 K  | eval
# 88   | unet.down_blocks.1                                                  | CrossAttnDownBlock2D    | 37.5 M | eval
# 89   | unet.down_blocks.1.attentions                                       | ModuleList              | 19.0 M | eval
# 90   | unet.down_blocks.1.attentions.0                                     | Transformer2DModel      | 9.5 M  | eval
# 91   | unet.down_blocks.1.attentions.0.norm                                | GroupNorm               | 1.3 K  | eval
# 92   | unet.down_blocks.1.attentions.0.proj_in                             | Linear                  | 410 K  | eval
# 93   | unet.down_blocks.1.attentions.0.transformer_blocks                  | ModuleList              | 8.7 M  | eval
# 94   | unet.down_blocks.1.attentions.0.transformer_blocks.0                | BasicTransformerBlock   | 8.7 M  | eval
# 95   | unet.down_blocks.1.attentions.0.transformer_blocks.0.norm1          | LayerNorm               | 1.3 K  | eval
# 96   | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn1          | Attention               | 1.6 M  | eval
# 97   | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_q     | Linear                  | 409 K  | eval
# 98   | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_k     | Linear                  | 409 K  | eval
# 99   | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_v     | Linear                  | 409 K  | eval
# 100  | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out   | ModuleList              | 410 K  | eval
# 101  | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0 | Linear                  | 410 K  | eval
# 102  | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.1 | Dropout                 | 0      | eval
# 103  | unet.down_blocks.1.attentions.0.transformer_blocks.0.norm2          | LayerNorm               | 1.3 K  | eval
# 104  | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn2          | Attention               | 2.1 M  | eval
# 105  | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_q     | Linear                  | 409 K  | eval
# 106  | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_k     | Linear                  | 655 K  | eval
# 107  | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_v     | Linear                  | 655 K  | eval
# 108  | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out   | ModuleList              | 410 K  | eval
# 109  | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0 | Linear                  | 410 K  | eval
# 110  | unet.down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.1 | Dropout                 | 0      | eval
# 111  | unet.down_blocks.1.attentions.0.transformer_blocks.0.norm3          | LayerNorm               | 1.3 K  | eval
# 112  | unet.down_blocks.1.attentions.0.transformer_blocks.0.ff             | FeedForward             | 4.9 M  | eval
# 113  | unet.down_blocks.1.attentions.0.transformer_blocks.0.ff.net         | ModuleList              | 4.9 M  | eval
# 114  | unet.down_blocks.1.attentions.0.transformer_blocks.0.ff.net.0       | GEGLU                   | 3.3 M  | eval
# 115  | unet.down_blocks.1.attentions.0.transformer_blocks.0.ff.net.0.proj  | Linear                  | 3.3 M  | eval
# 116  | unet.down_blocks.1.attentions.0.transformer_blocks.0.ff.net.1       | Dropout                 | 0      | eval
# 117  | unet.down_blocks.1.attentions.0.transformer_blocks.0.ff.net.2       | Linear                  | 1.6 M  | eval
# 118  | unet.down_blocks.1.attentions.0.proj_out                            | Linear                  | 410 K  | eval
# 119  | unet.down_blocks.1.attentions.1                                     | Transformer2DModel      | 9.5 M  | eval
# 120  | unet.down_blocks.1.attentions.1.norm                                | GroupNorm               | 1.3 K  | eval
# 121  | unet.down_blocks.1.attentions.1.proj_in                             | Linear                  | 410 K  | eval
# 122  | unet.down_blocks.1.attentions.1.transformer_blocks                  | ModuleList              | 8.7 M  | eval
# 123  | unet.down_blocks.1.attentions.1.transformer_blocks.0                | BasicTransformerBlock   | 8.7 M  | eval
# 124  | unet.down_blocks.1.attentions.1.transformer_blocks.0.norm1          | LayerNorm               | 1.3 K  | eval
# 125  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn1          | Attention               | 1.6 M  | eval
# 126  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_q     | Linear                  | 409 K  | eval
# 127  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_k     | Linear                  | 409 K  | eval
# 128  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_v     | Linear                  | 409 K  | eval
# 129  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out   | ModuleList              | 410 K  | eval
# 130  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out.0 | Linear                  | 410 K  | eval
# 131  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out.1 | Dropout                 | 0      | eval
# 132  | unet.down_blocks.1.attentions.1.transformer_blocks.0.norm2          | LayerNorm               | 1.3 K  | eval
# 133  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn2          | Attention               | 2.1 M  | eval
# 134  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_q     | Linear                  | 409 K  | eval
# 135  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_k     | Linear                  | 655 K  | eval
# 136  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_v     | Linear                  | 655 K  | eval
# 137  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out   | ModuleList              | 410 K  | eval
# 138  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out.0 | Linear                  | 410 K  | eval
# 139  | unet.down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out.1 | Dropout                 | 0      | eval
# 140  | unet.down_blocks.1.attentions.1.transformer_blocks.0.norm3          | LayerNorm               | 1.3 K  | eval
# 141  | unet.down_blocks.1.attentions.1.transformer_blocks.0.ff             | FeedForward             | 4.9 M  | eval
# 142  | unet.down_blocks.1.attentions.1.transformer_blocks.0.ff.net         | ModuleList              | 4.9 M  | eval
# 143  | unet.down_blocks.1.attentions.1.transformer_blocks.0.ff.net.0       | GEGLU                   | 3.3 M  | eval
# 144  | unet.down_blocks.1.attentions.1.transformer_blocks.0.ff.net.0.proj  | Linear                  | 3.3 M  | eval
# 145  | unet.down_blocks.1.attentions.1.transformer_blocks.0.ff.net.1       | Dropout                 | 0      | eval
# 146  | unet.down_blocks.1.attentions.1.transformer_blocks.0.ff.net.2       | Linear                  | 1.6 M  | eval
# 147  | unet.down_blocks.1.attentions.1.proj_out                            | Linear                  | 410 K  | eval
# 148  | unet.down_blocks.1.resnets                                          | ModuleList              | 14.8 M | eval
# 149  | unet.down_blocks.1.resnets.0                                        | ResnetBlock2D           | 6.6 M  | eval
# 150  | unet.down_blocks.1.resnets.0.norm1                                  | GroupNorm               | 640    | eval
# 151  | unet.down_blocks.1.resnets.0.conv1                                  | Conv2d                  | 1.8 M  | eval
# 152  | unet.down_blocks.1.resnets.0.time_emb_proj                          | Linear                  | 819 K  | eval
# 153  | unet.down_blocks.1.resnets.0.norm2                                  | GroupNorm               | 1.3 K  | eval
# 154  | unet.down_blocks.1.resnets.0.dropout                                | Dropout                 | 0      | eval
# 155  | unet.down_blocks.1.resnets.0.conv2                                  | Conv2d                  | 3.7 M  | eval
# 156  | unet.down_blocks.1.resnets.0.nonlinearity                           | SiLU                    | 0      | eval
# 157  | unet.down_blocks.1.resnets.0.conv_shortcut                          | Conv2d                  | 205 K  | eval
# 158  | unet.down_blocks.1.resnets.1                                        | ResnetBlock2D           | 8.2 M  | eval
# 159  | unet.down_blocks.1.resnets.1.norm1                                  | GroupNorm               | 1.3 K  | eval
# 160  | unet.down_blocks.1.resnets.1.conv1                                  | Conv2d                  | 3.7 M  | eval
# 161  | unet.down_blocks.1.resnets.1.time_emb_proj                          | Linear                  | 819 K  | eval
# 162  | unet.down_blocks.1.resnets.1.norm2                                  | GroupNorm               | 1.3 K  | eval
# 163  | unet.down_blocks.1.resnets.1.dropout                                | Dropout                 | 0      | eval
# 164  | unet.down_blocks.1.resnets.1.conv2                                  | Conv2d                  | 3.7 M  | eval
# 165  | unet.down_blocks.1.resnets.1.nonlinearity                           | SiLU                    | 0      | eval
# 166  | unet.down_blocks.1.downsamplers                                     | ModuleList              | 3.7 M  | eval
# 167  | unet.down_blocks.1.downsamplers.0                                   | Downsample2D            | 3.7 M  | eval
# 168  | unet.down_blocks.1.downsamplers.0.conv                              | Conv2d                  | 3.7 M  | eval
# 169  | unet.down_blocks.2                                                  | CrossAttnDownBlock2D    | 141 M  | eval
# 170  | unet.down_blocks.2.attentions                                       | ModuleList              | 70.8 M | eval
# 171  | unet.down_blocks.2.attentions.0                                     | Transformer2DModel      | 35.4 M | eval
# 172  | unet.down_blocks.2.attentions.0.norm                                | GroupNorm               | 2.6 K  | eval
# 173  | unet.down_blocks.2.attentions.0.proj_in                             | Linear                  | 1.6 M  | eval
# 174  | unet.down_blocks.2.attentions.0.transformer_blocks                  | ModuleList              | 32.1 M | eval
# 175  | unet.down_blocks.2.attentions.0.transformer_blocks.0                | BasicTransformerBlock   | 32.1 M | eval
# 176  | unet.down_blocks.2.attentions.0.transformer_blocks.0.norm1          | LayerNorm               | 2.6 K  | eval
# 177  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn1          | Attention               | 6.6 M  | eval
# 178  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_q     | Linear                  | 1.6 M  | eval
# 179  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_k     | Linear                  | 1.6 M  | eval
# 180  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_v     | Linear                  | 1.6 M  | eval
# 181  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_out   | ModuleList              | 1.6 M  | eval
# 182  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_out.0 | Linear                  | 1.6 M  | eval
# 183  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_out.1 | Dropout                 | 0      | eval
# 184  | unet.down_blocks.2.attentions.0.transformer_blocks.0.norm2          | LayerNorm               | 2.6 K  | eval
# 185  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn2          | Attention               | 5.9 M  | eval
# 186  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_q     | Linear                  | 1.6 M  | eval
# 187  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_k     | Linear                  | 1.3 M  | eval
# 188  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_v     | Linear                  | 1.3 M  | eval
# 189  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_out   | ModuleList              | 1.6 M  | eval
# 190  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_out.0 | Linear                  | 1.6 M  | eval
# 191  | unet.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_out.1 | Dropout                 | 0      | eval
# 192  | unet.down_blocks.2.attentions.0.transformer_blocks.0.norm3          | LayerNorm               | 2.6 K  | eval
# 193  | unet.down_blocks.2.attentions.0.transformer_blocks.0.ff             | FeedForward             | 19.7 M | eval
# 194  | unet.down_blocks.2.attentions.0.transformer_blocks.0.ff.net         | ModuleList              | 19.7 M | eval
# 195  | unet.down_blocks.2.attentions.0.transformer_blocks.0.ff.net.0       | GEGLU                   | 13.1 M | eval
# 196  | unet.down_blocks.2.attentions.0.transformer_blocks.0.ff.net.0.proj  | Linear                  | 13.1 M | eval
# 197  | unet.down_blocks.2.attentions.0.transformer_blocks.0.ff.net.1       | Dropout                 | 0      | eval
# 198  | unet.down_blocks.2.attentions.0.transformer_blocks.0.ff.net.2       | Linear                  | 6.6 M  | eval
# 199  | unet.down_blocks.2.attentions.0.proj_out                            | Linear                  | 1.6 M  | eval
# 200  | unet.down_blocks.2.attentions.1                                     | Transformer2DModel      | 35.4 M | eval
# 201  | unet.down_blocks.2.attentions.1.norm                                | GroupNorm               | 2.6 K  | eval
# 202  | unet.down_blocks.2.attentions.1.proj_in                             | Linear                  | 1.6 M  | eval
# 203  | unet.down_blocks.2.attentions.1.transformer_blocks                  | ModuleList              | 32.1 M | eval
# 204  | unet.down_blocks.2.attentions.1.transformer_blocks.0                | BasicTransformerBlock   | 32.1 M | eval
# 205  | unet.down_blocks.2.attentions.1.transformer_blocks.0.norm1          | LayerNorm               | 2.6 K  | eval
# 206  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn1          | Attention               | 6.6 M  | eval
# 207  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_q     | Linear                  | 1.6 M  | eval
# 208  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_k     | Linear                  | 1.6 M  | eval
# 209  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_v     | Linear                  | 1.6 M  | eval
# 210  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_out   | ModuleList              | 1.6 M  | eval
# 211  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_out.0 | Linear                  | 1.6 M  | eval
# 212  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_out.1 | Dropout                 | 0      | eval
# 213  | unet.down_blocks.2.attentions.1.transformer_blocks.0.norm2          | LayerNorm               | 2.6 K  | eval
# 214  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn2          | Attention               | 5.9 M  | eval
# 215  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_q     | Linear                  | 1.6 M  | eval
# 216  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_k     | Linear                  | 1.3 M  | eval
# 217  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_v     | Linear                  | 1.3 M  | eval
# 218  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_out   | ModuleList              | 1.6 M  | eval
# 219  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_out.0 | Linear                  | 1.6 M  | eval
# 220  | unet.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_out.1 | Dropout                 | 0      | eval
# 221  | unet.down_blocks.2.attentions.1.transformer_blocks.0.norm3          | LayerNorm               | 2.6 K  | eval
# 222  | unet.down_blocks.2.attentions.1.transformer_blocks.0.ff             | FeedForward             | 19.7 M | eval
# 223  | unet.down_blocks.2.attentions.1.transformer_blocks.0.ff.net         | ModuleList              | 19.7 M | eval
# 224  | unet.down_blocks.2.attentions.1.transformer_blocks.0.ff.net.0       | GEGLU                   | 13.1 M | eval
# 225  | unet.down_blocks.2.attentions.1.transformer_blocks.0.ff.net.0.proj  | Linear                  | 13.1 M | eval
# 226  | unet.down_blocks.2.attentions.1.transformer_blocks.0.ff.net.1       | Dropout                 | 0      | eval
# 227  | unet.down_blocks.2.attentions.1.transformer_blocks.0.ff.net.2       | Linear                  | 6.6 M  | eval
# 228  | unet.down_blocks.2.attentions.1.proj_out                            | Linear                  | 1.6 M  | eval
# 229  | unet.down_blocks.2.resnets                                          | ModuleList              | 55.7 M | eval
# 230  | unet.down_blocks.2.resnets.0                                        | ResnetBlock2D           | 24.6 M | eval
# 231  | unet.down_blocks.2.resnets.0.norm1                                  | GroupNorm               | 1.3 K  | eval
# 232  | unet.down_blocks.2.resnets.0.conv1                                  | Conv2d                  | 7.4 M  | eval
# 233  | unet.down_blocks.2.resnets.0.time_emb_proj                          | Linear                  | 1.6 M  | eval
# 234  | unet.down_blocks.2.resnets.0.norm2                                  | GroupNorm               | 2.6 K  | eval
# 235  | unet.down_blocks.2.resnets.0.dropout                                | Dropout                 | 0      | eval
# 236  | unet.down_blocks.2.resnets.0.conv2                                  | Conv2d                  | 14.7 M | eval
# 237  | unet.down_blocks.2.resnets.0.nonlinearity                           | SiLU                    | 0      | eval
# 238  | unet.down_blocks.2.resnets.0.conv_shortcut                          | Conv2d                  | 820 K  | eval
# 239  | unet.down_blocks.2.resnets.1                                        | ResnetBlock2D           | 31.1 M | eval
# 240  | unet.down_blocks.2.resnets.1.norm1                                  | GroupNorm               | 2.6 K  | eval
# 241  | unet.down_blocks.2.resnets.1.conv1                                  | Conv2d                  | 14.7 M | eval
# 242  | unet.down_blocks.2.resnets.1.time_emb_proj                          | Linear                  | 1.6 M  | eval
# 243  | unet.down_blocks.2.resnets.1.norm2                                  | GroupNorm               | 2.6 K  | eval
# 244  | unet.down_blocks.2.resnets.1.dropout                                | Dropout                 | 0      | eval
# 245  | unet.down_blocks.2.resnets.1.conv2                                  | Conv2d                  | 14.7 M | eval
# 246  | unet.down_blocks.2.resnets.1.nonlinearity                           | SiLU                    | 0      | eval
# 247  | unet.down_blocks.2.downsamplers                                     | ModuleList              | 14.7 M | eval
# 248  | unet.down_blocks.2.downsamplers.0                                   | Downsample2D            | 14.7 M | eval
# 249  | unet.down_blocks.2.downsamplers.0.conv                              | Conv2d                  | 14.7 M | eval
# 250  | unet.down_blocks.3                                                  | DownBlock2D             | 62.3 M | eval
# 251  | unet.down_blocks.3.resnets                                          | ModuleList              | 62.3 M | eval
# 252  | unet.down_blocks.3.resnets.0                                        | ResnetBlock2D           | 31.1 M | eval
# 253  | unet.down_blocks.3.resnets.0.norm1                                  | GroupNorm               | 2.6 K  | eval
# 254  | unet.down_blocks.3.resnets.0.conv1                                  | Conv2d                  | 14.7 M | eval
# 255  | unet.down_blocks.3.resnets.0.time_emb_proj                          | Linear                  | 1.6 M  | eval
# 256  | unet.down_blocks.3.resnets.0.norm2                                  | GroupNorm               | 2.6 K  | eval
# 257  | unet.down_blocks.3.resnets.0.dropout                                | Dropout                 | 0      | eval
# 258  | unet.down_blocks.3.resnets.0.conv2                                  | Conv2d                  | 14.7 M | eval
# 259  | unet.down_blocks.3.resnets.0.nonlinearity                           | SiLU                    | 0      | eval
# 260  | unet.down_blocks.3.resnets.1                                        | ResnetBlock2D           | 31.1 M | eval
# 261  | unet.down_blocks.3.resnets.1.norm1                                  | GroupNorm               | 2.6 K  | eval
# 262  | unet.down_blocks.3.resnets.1.conv1                                  | Conv2d                  | 14.7 M | eval
# 263  | unet.down_blocks.3.resnets.1.time_emb_proj                          | Linear                  | 1.6 M  | eval
# 264  | unet.down_blocks.3.resnets.1.norm2                                  | GroupNorm               | 2.6 K  | eval
# 265  | unet.down_blocks.3.resnets.1.dropout                                | Dropout                 | 0      | eval
# 266  | unet.down_blocks.3.resnets.1.conv2                                  | Conv2d                  | 14.7 M | eval
# 267  | unet.down_blocks.3.resnets.1.nonlinearity                           | SiLU                    | 0      | eval
# 268  | unet.up_blocks                                                      | ModuleList              | 514 M  | eval
# 269  | unet.up_blocks.0                                                    | UpBlock2D               | 162 M  | eval
# 270  | unet.up_blocks.0.resnets                                            | ModuleList              | 147 M  | eval
# 271  | unet.up_blocks.0.resnets.0                                          | ResnetBlock2D           | 49.2 M | eval
# 272  | unet.up_blocks.0.resnets.0.norm1                                    | GroupNorm               | 5.1 K  | eval
# 273  | unet.up_blocks.0.resnets.0.conv1                                    | Conv2d                  | 29.5 M | eval
# 274  | unet.up_blocks.0.resnets.0.time_emb_proj                            | Linear                  | 1.6 M  | eval
# 275  | unet.up_blocks.0.resnets.0.norm2                                    | GroupNorm               | 2.6 K  | eval
# 276  | unet.up_blocks.0.resnets.0.dropout                                  | Dropout                 | 0      | eval
# 277  | unet.up_blocks.0.resnets.0.conv2                                    | Conv2d                  | 14.7 M | eval
# 278  | unet.up_blocks.0.resnets.0.nonlinearity                             | SiLU                    | 0      | eval
# 279  | unet.up_blocks.0.resnets.0.conv_shortcut                            | Conv2d                  | 3.3 M  | eval
# 280  | unet.up_blocks.0.resnets.1                                          | ResnetBlock2D           | 49.2 M | eval
# 281  | unet.up_blocks.0.resnets.1.norm1                                    | GroupNorm               | 5.1 K  | eval
# 282  | unet.up_blocks.0.resnets.1.conv1                                    | Conv2d                  | 29.5 M | eval
# 283  | unet.up_blocks.0.resnets.1.time_emb_proj                            | Linear                  | 1.6 M  | eval
# 284  | unet.up_blocks.0.resnets.1.norm2                                    | GroupNorm               | 2.6 K  | eval
# 285  | unet.up_blocks.0.resnets.1.dropout                                  | Dropout                 | 0      | eval
# 286  | unet.up_blocks.0.resnets.1.conv2                                    | Conv2d                  | 14.7 M | eval
# 287  | unet.up_blocks.0.resnets.1.nonlinearity                             | SiLU                    | 0      | eval
# 288  | unet.up_blocks.0.resnets.1.conv_shortcut                            | Conv2d                  | 3.3 M  | eval
# 289  | unet.up_blocks.0.resnets.2                                          | ResnetBlock2D           | 49.2 M | eval
# 290  | unet.up_blocks.0.resnets.2.norm1                                    | GroupNorm               | 5.1 K  | eval
# 291  | unet.up_blocks.0.resnets.2.conv1                                    | Conv2d                  | 29.5 M | eval
# 292  | unet.up_blocks.0.resnets.2.time_emb_proj                            | Linear                  | 1.6 M  | eval
# 293  | unet.up_blocks.0.resnets.2.norm2                                    | GroupNorm               | 2.6 K  | eval
# 294  | unet.up_blocks.0.resnets.2.dropout                                  | Dropout                 | 0      | eval
# 295  | unet.up_blocks.0.resnets.2.conv2                                    | Conv2d                  | 14.7 M | eval
# 296  | unet.up_blocks.0.resnets.2.nonlinearity                             | SiLU                    | 0      | eval
# 297  | unet.up_blocks.0.resnets.2.conv_shortcut                            | Conv2d                  | 3.3 M  | eval
# 298  | unet.up_blocks.0.upsamplers                                         | ModuleList              | 14.7 M | eval
# 299  | unet.up_blocks.0.upsamplers.0                                       | Upsample2D              | 14.7 M | eval
# 300  | unet.up_blocks.0.upsamplers.0.conv                                  | Conv2d                  | 14.7 M | eval
# 301  | unet.up_blocks.1                                                    | CrossAttnUpBlock2D      | 260 M  | eval
# 302  | unet.up_blocks.1.attentions                                         | ModuleList              | 106 M  | eval
# 303  | unet.up_blocks.1.attentions.0                                       | Transformer2DModel      | 35.4 M | eval
# 304  | unet.up_blocks.1.attentions.0.norm                                  | GroupNorm               | 2.6 K  | eval
# 305  | unet.up_blocks.1.attentions.0.proj_in                               | Linear                  | 1.6 M  | eval
# 306  | unet.up_blocks.1.attentions.0.transformer_blocks                    | ModuleList              | 32.1 M | eval
# 307  | unet.up_blocks.1.attentions.0.transformer_blocks.0                  | BasicTransformerBlock   | 32.1 M | eval
# 308  | unet.up_blocks.1.attentions.0.transformer_blocks.0.norm1            | LayerNorm               | 2.6 K  | eval
# 309  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn1            | Attention               | 6.6 M  | eval
# 310  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_q       | Linear                  | 1.6 M  | eval
# 311  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_k       | Linear                  | 1.6 M  | eval
# 312  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_v       | Linear                  | 1.6 M  | eval
# 313  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out     | ModuleList              | 1.6 M  | eval
# 314  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0   | Linear                  | 1.6 M  | eval
# 315  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.1   | Dropout                 | 0      | eval
# 316  | unet.up_blocks.1.attentions.0.transformer_blocks.0.norm2            | LayerNorm               | 2.6 K  | eval
# 317  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn2            | Attention               | 5.9 M  | eval
# 318  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_q       | Linear                  | 1.6 M  | eval
# 319  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_k       | Linear                  | 1.3 M  | eval
# 320  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_v       | Linear                  | 1.3 M  | eval
# 321  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out     | ModuleList              | 1.6 M  | eval
# 322  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0   | Linear                  | 1.6 M  | eval
# 323  | unet.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.1   | Dropout                 | 0      | eval
# 324  | unet.up_blocks.1.attentions.0.transformer_blocks.0.norm3            | LayerNorm               | 2.6 K  | eval
# 325  | unet.up_blocks.1.attentions.0.transformer_blocks.0.ff               | FeedForward             | 19.7 M | eval
# 326  | unet.up_blocks.1.attentions.0.transformer_blocks.0.ff.net           | ModuleList              | 19.7 M | eval
# 327  | unet.up_blocks.1.attentions.0.transformer_blocks.0.ff.net.0         | GEGLU                   | 13.1 M | eval
# 328  | unet.up_blocks.1.attentions.0.transformer_blocks.0.ff.net.0.proj    | Linear                  | 13.1 M | eval
# 329  | unet.up_blocks.1.attentions.0.transformer_blocks.0.ff.net.1         | Dropout                 | 0      | eval
# 330  | unet.up_blocks.1.attentions.0.transformer_blocks.0.ff.net.2         | Linear                  | 6.6 M  | eval
# 331  | unet.up_blocks.1.attentions.0.proj_out                              | Linear                  | 1.6 M  | eval
# 332  | unet.up_blocks.1.attentions.1                                       | Transformer2DModel      | 35.4 M | eval
# 333  | unet.up_blocks.1.attentions.1.norm                                  | GroupNorm               | 2.6 K  | eval
# 334  | unet.up_blocks.1.attentions.1.proj_in                               | Linear                  | 1.6 M  | eval
# 335  | unet.up_blocks.1.attentions.1.transformer_blocks                    | ModuleList              | 32.1 M | eval
# 336  | unet.up_blocks.1.attentions.1.transformer_blocks.0                  | BasicTransformerBlock   | 32.1 M | eval
# 337  | unet.up_blocks.1.attentions.1.transformer_blocks.0.norm1            | LayerNorm               | 2.6 K  | eval
# 338  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn1            | Attention               | 6.6 M  | eval
# 339  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_q       | Linear                  | 1.6 M  | eval
# 340  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_k       | Linear                  | 1.6 M  | eval
# 341  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_v       | Linear                  | 1.6 M  | eval
# 342  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out     | ModuleList              | 1.6 M  | eval
# 343  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out.0   | Linear                  | 1.6 M  | eval
# 344  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out.1   | Dropout                 | 0      | eval
# 345  | unet.up_blocks.1.attentions.1.transformer_blocks.0.norm2            | LayerNorm               | 2.6 K  | eval
# 346  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn2            | Attention               | 5.9 M  | eval
# 347  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_q       | Linear                  | 1.6 M  | eval
# 348  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_k       | Linear                  | 1.3 M  | eval
# 349  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_v       | Linear                  | 1.3 M  | eval
# 350  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out     | ModuleList              | 1.6 M  | eval
# 351  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out.0   | Linear                  | 1.6 M  | eval
# 352  | unet.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out.1   | Dropout                 | 0      | eval
# 353  | unet.up_blocks.1.attentions.1.transformer_blocks.0.norm3            | LayerNorm               | 2.6 K  | eval
# 354  | unet.up_blocks.1.attentions.1.transformer_blocks.0.ff               | FeedForward             | 19.7 M | eval
# 355  | unet.up_blocks.1.attentions.1.transformer_blocks.0.ff.net           | ModuleList              | 19.7 M | eval
# 356  | unet.up_blocks.1.attentions.1.transformer_blocks.0.ff.net.0         | GEGLU                   | 13.1 M | eval
# 357  | unet.up_blocks.1.attentions.1.transformer_blocks.0.ff.net.0.proj    | Linear                  | 13.1 M | eval
# 358  | unet.up_blocks.1.attentions.1.transformer_blocks.0.ff.net.1         | Dropout                 | 0      | eval
# 359  | unet.up_blocks.1.attentions.1.transformer_blocks.0.ff.net.2         | Linear                  | 6.6 M  | eval
# 360  | unet.up_blocks.1.attentions.1.proj_out                              | Linear                  | 1.6 M  | eval
# 361  | unet.up_blocks.1.attentions.2                                       | Transformer2DModel      | 35.4 M | eval
# 362  | unet.up_blocks.1.attentions.2.norm                                  | GroupNorm               | 2.6 K  | eval
# 363  | unet.up_blocks.1.attentions.2.proj_in                               | Linear                  | 1.6 M  | eval
# 364  | unet.up_blocks.1.attentions.2.transformer_blocks                    | ModuleList              | 32.1 M | eval
# 365  | unet.up_blocks.1.attentions.2.transformer_blocks.0                  | BasicTransformerBlock   | 32.1 M | eval
# 366  | unet.up_blocks.1.attentions.2.transformer_blocks.0.norm1            | LayerNorm               | 2.6 K  | eval
# 367  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn1            | Attention               | 6.6 M  | eval
# 368  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_q       | Linear                  | 1.6 M  | eval
# 369  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_k       | Linear                  | 1.6 M  | eval
# 370  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_v       | Linear                  | 1.6 M  | eval
# 371  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_out     | ModuleList              | 1.6 M  | eval
# 372  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_out.0   | Linear                  | 1.6 M  | eval
# 373  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_out.1   | Dropout                 | 0      | eval
# 374  | unet.up_blocks.1.attentions.2.transformer_blocks.0.norm2            | LayerNorm               | 2.6 K  | eval
# 375  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn2            | Attention               | 5.9 M  | eval
# 376  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_q       | Linear                  | 1.6 M  | eval
# 377  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_k       | Linear                  | 1.3 M  | eval
# 378  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_v       | Linear                  | 1.3 M  | eval
# 379  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_out     | ModuleList              | 1.6 M  | eval
# 380  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_out.0   | Linear                  | 1.6 M  | eval
# 381  | unet.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_out.1   | Dropout                 | 0      | eval
# 382  | unet.up_blocks.1.attentions.2.transformer_blocks.0.norm3            | LayerNorm               | 2.6 K  | eval
# 383  | unet.up_blocks.1.attentions.2.transformer_blocks.0.ff               | FeedForward             | 19.7 M | eval
# 384  | unet.up_blocks.1.attentions.2.transformer_blocks.0.ff.net           | ModuleList              | 19.7 M | eval
# 385  | unet.up_blocks.1.attentions.2.transformer_blocks.0.ff.net.0         | GEGLU                   | 13.1 M | eval
# 386  | unet.up_blocks.1.attentions.2.transformer_blocks.0.ff.net.0.proj    | Linear                  | 13.1 M | eval
# 387  | unet.up_blocks.1.attentions.2.transformer_blocks.0.ff.net.1         | Dropout                 | 0      | eval
# 388  | unet.up_blocks.1.attentions.2.transformer_blocks.0.ff.net.2         | Linear                  | 6.6 M  | eval
# 389  | unet.up_blocks.1.attentions.2.proj_out                              | Linear                  | 1.6 M  | eval
# 390  | unet.up_blocks.1.resnets                                            | ModuleList              | 139 M  | eval
# 391  | unet.up_blocks.1.resnets.0                                          | ResnetBlock2D           | 49.2 M | eval
# 392  | unet.up_blocks.1.resnets.0.norm1                                    | GroupNorm               | 5.1 K  | eval
# 393  | unet.up_blocks.1.resnets.0.conv1                                    | Conv2d                  | 29.5 M | eval
# 394  | unet.up_blocks.1.resnets.0.time_emb_proj                            | Linear                  | 1.6 M  | eval
# 395  | unet.up_blocks.1.resnets.0.norm2                                    | GroupNorm               | 2.6 K  | eval
# 396  | unet.up_blocks.1.resnets.0.dropout                                  | Dropout                 | 0      | eval
# 397  | unet.up_blocks.1.resnets.0.conv2                                    | Conv2d                  | 14.7 M | eval
# 398  | unet.up_blocks.1.resnets.0.nonlinearity                             | SiLU                    | 0      | eval
# 399  | unet.up_blocks.1.resnets.0.conv_shortcut                            | Conv2d                  | 3.3 M  | eval
# 400  | unet.up_blocks.1.resnets.1                                          | ResnetBlock2D           | 49.2 M | eval
# 401  | unet.up_blocks.1.resnets.1.norm1                                    | GroupNorm               | 5.1 K  | eval
# 402  | unet.up_blocks.1.resnets.1.conv1                                    | Conv2d                  | 29.5 M | eval
# 403  | unet.up_blocks.1.resnets.1.time_emb_proj                            | Linear                  | 1.6 M  | eval
# 404  | unet.up_blocks.1.resnets.1.norm2                                    | GroupNorm               | 2.6 K  | eval
# 405  | unet.up_blocks.1.resnets.1.dropout                                  | Dropout                 | 0      | eval
# 406  | unet.up_blocks.1.resnets.1.conv2                                    | Conv2d                  | 14.7 M | eval
# 407  | unet.up_blocks.1.resnets.1.nonlinearity                             | SiLU                    | 0      | eval
# ...
# 1102 | text_encoder.text_model.encoder.layers.11.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1103 | text_encoder.text_model.encoder.layers.12                           | CLIPEncoderLayer        | 12.6 M | eval
# 1104 | text_encoder.text_model.encoder.layers.12.self_attn                 | CLIPAttention           | 4.2 M  | eval
# 1105 | text_encoder.text_model.encoder.layers.12.self_attn.k_proj          | Linear                  | 1.0 M  | eval
# 1106 | text_encoder.text_model.encoder.layers.12.self_attn.v_proj          | Linear                  | 1.0 M  | eval
# 1107 | text_encoder.text_model.encoder.layers.12.self_attn.q_proj          | Linear                  | 1.0 M  | eval
# 1108 | text_encoder.text_model.encoder.layers.12.self_attn.out_proj        | Linear                  | 1.0 M  | eval
# 1109 | text_encoder.text_model.encoder.layers.12.layer_norm1               | LayerNorm               | 2.0 K  | eval
# 1110 | text_encoder.text_model.encoder.layers.12.mlp                       | CLIPMLP                 | 8.4 M  | eval
# 1111 | text_encoder.text_model.encoder.layers.12.mlp.activation_fn         | GELUActivation          | 0      | eval
# 1112 | text_encoder.text_model.encoder.layers.12.mlp.fc1                   | Linear                  | 4.2 M  | eval
# 1113 | text_encoder.text_model.encoder.layers.12.mlp.fc2                   | Linear                  | 4.2 M  | eval
# 1114 | text_encoder.text_model.encoder.layers.12.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1115 | text_encoder.text_model.encoder.layers.13                           | CLIPEncoderLayer        | 12.6 M | eval
# 1116 | text_encoder.text_model.encoder.layers.13.self_attn                 | CLIPAttention           | 4.2 M  | eval
# 1117 | text_encoder.text_model.encoder.layers.13.self_attn.k_proj          | Linear                  | 1.0 M  | eval
# 1118 | text_encoder.text_model.encoder.layers.13.self_attn.v_proj          | Linear                  | 1.0 M  | eval
# 1119 | text_encoder.text_model.encoder.layers.13.self_attn.q_proj          | Linear                  | 1.0 M  | eval
# 1120 | text_encoder.text_model.encoder.layers.13.self_attn.out_proj        | Linear                  | 1.0 M  | eval
# 1121 | text_encoder.text_model.encoder.layers.13.layer_norm1               | LayerNorm               | 2.0 K  | eval
# 1122 | text_encoder.text_model.encoder.layers.13.mlp                       | CLIPMLP                 | 8.4 M  | eval
# 1123 | text_encoder.text_model.encoder.layers.13.mlp.activation_fn         | GELUActivation          | 0      | eval
# 1124 | text_encoder.text_model.encoder.layers.13.mlp.fc1                   | Linear                  | 4.2 M  | eval
# 1125 | text_encoder.text_model.encoder.layers.13.mlp.fc2                   | Linear                  | 4.2 M  | eval
# 1126 | text_encoder.text_model.encoder.layers.13.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1127 | text_encoder.text_model.encoder.layers.14                           | CLIPEncoderLayer        | 12.6 M | eval
# 1128 | text_encoder.text_model.encoder.layers.14.self_attn                 | CLIPAttention           | 4.2 M  | eval
# 1129 | text_encoder.text_model.encoder.layers.14.self_attn.k_proj          | Linear                  | 1.0 M  | eval
# 1130 | text_encoder.text_model.encoder.layers.14.self_attn.v_proj          | Linear                  | 1.0 M  | eval
# 1131 | text_encoder.text_model.encoder.layers.14.self_attn.q_proj          | Linear                  | 1.0 M  | eval
# 1132 | text_encoder.text_model.encoder.layers.14.self_attn.out_proj        | Linear                  | 1.0 M  | eval
# 1133 | text_encoder.text_model.encoder.layers.14.layer_norm1               | LayerNorm               | 2.0 K  | eval
# 1134 | text_encoder.text_model.encoder.layers.14.mlp                       | CLIPMLP                 | 8.4 M  | eval
# 1135 | text_encoder.text_model.encoder.layers.14.mlp.activation_fn         | GELUActivation          | 0      | eval
# 1136 | text_encoder.text_model.encoder.layers.14.mlp.fc1                   | Linear                  | 4.2 M  | eval
# 1137 | text_encoder.text_model.encoder.layers.14.mlp.fc2                   | Linear                  | 4.2 M  | eval
# 1138 | text_encoder.text_model.encoder.layers.14.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1139 | text_encoder.text_model.encoder.layers.15                           | CLIPEncoderLayer        | 12.6 M | eval
# 1140 | text_encoder.text_model.encoder.layers.15.self_attn                 | CLIPAttention           | 4.2 M  | eval
# 1141 | text_encoder.text_model.encoder.layers.15.self_attn.k_proj          | Linear                  | 1.0 M  | eval
# 1142 | text_encoder.text_model.encoder.layers.15.self_attn.v_proj          | Linear                  | 1.0 M  | eval
# 1143 | text_encoder.text_model.encoder.layers.15.self_attn.q_proj          | Linear                  | 1.0 M  | eval
# 1144 | text_encoder.text_model.encoder.layers.15.self_attn.out_proj        | Linear                  | 1.0 M  | eval
# 1145 | text_encoder.text_model.encoder.layers.15.layer_norm1               | LayerNorm               | 2.0 K  | eval
# 1146 | text_encoder.text_model.encoder.layers.15.mlp                       | CLIPMLP                 | 8.4 M  | eval
# 1147 | text_encoder.text_model.encoder.layers.15.mlp.activation_fn         | GELUActivation          | 0      | eval
# 1148 | text_encoder.text_model.encoder.layers.15.mlp.fc1                   | Linear                  | 4.2 M  | eval
# 1149 | text_encoder.text_model.encoder.layers.15.mlp.fc2                   | Linear                  | 4.2 M  | eval
# 1150 | text_encoder.text_model.encoder.layers.15.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1151 | text_encoder.text_model.encoder.layers.16                           | CLIPEncoderLayer        | 12.6 M | eval
# 1152 | text_encoder.text_model.encoder.layers.16.self_attn                 | CLIPAttention           | 4.2 M  | eval
# 1153 | text_encoder.text_model.encoder.layers.16.self_attn.k_proj          | Linear                  | 1.0 M  | eval
# 1154 | text_encoder.text_model.encoder.layers.16.self_attn.v_proj          | Linear                  | 1.0 M  | eval
# 1155 | text_encoder.text_model.encoder.layers.16.self_attn.q_proj          | Linear                  | 1.0 M  | eval
# 1156 | text_encoder.text_model.encoder.layers.16.self_attn.out_proj        | Linear                  | 1.0 M  | eval
# 1157 | text_encoder.text_model.encoder.layers.16.layer_norm1               | LayerNorm               | 2.0 K  | eval
# 1158 | text_encoder.text_model.encoder.layers.16.mlp                       | CLIPMLP                 | 8.4 M  | eval
# 1159 | text_encoder.text_model.encoder.layers.16.mlp.activation_fn         | GELUActivation          | 0      | eval
# 1160 | text_encoder.text_model.encoder.layers.16.mlp.fc1                   | Linear                  | 4.2 M  | eval
# 1161 | text_encoder.text_model.encoder.layers.16.mlp.fc2                   | Linear                  | 4.2 M  | eval
# 1162 | text_encoder.text_model.encoder.layers.16.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1163 | text_encoder.text_model.encoder.layers.17                           | CLIPEncoderLayer        | 12.6 M | eval
# 1164 | text_encoder.text_model.encoder.layers.17.self_attn                 | CLIPAttention           | 4.2 M  | eval
# 1165 | text_encoder.text_model.encoder.layers.17.self_attn.k_proj          | Linear                  | 1.0 M  | eval
# 1166 | text_encoder.text_model.encoder.layers.17.self_attn.v_proj          | Linear                  | 1.0 M  | eval
# 1167 | text_encoder.text_model.encoder.layers.17.self_attn.q_proj          | Linear                  | 1.0 M  | eval
# 1168 | text_encoder.text_model.encoder.layers.17.self_attn.out_proj        | Linear                  | 1.0 M  | eval
# 1169 | text_encoder.text_model.encoder.layers.17.layer_norm1               | LayerNorm               | 2.0 K  | eval
# 1170 | text_encoder.text_model.encoder.layers.17.mlp                       | CLIPMLP                 | 8.4 M  | eval
# 1171 | text_encoder.text_model.encoder.layers.17.mlp.activation_fn         | GELUActivation          | 0      | eval
# 1172 | text_encoder.text_model.encoder.layers.17.mlp.fc1                   | Linear                  | 4.2 M  | eval
# 1173 | text_encoder.text_model.encoder.layers.17.mlp.fc2                   | Linear                  | 4.2 M  | eval
# 1174 | text_encoder.text_model.encoder.layers.17.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1175 | text_encoder.text_model.encoder.layers.18                           | CLIPEncoderLayer        | 12.6 M | eval
# 1176 | text_encoder.text_model.encoder.layers.18.self_attn                 | CLIPAttention           | 4.2 M  | eval
# 1177 | text_encoder.text_model.encoder.layers.18.self_attn.k_proj          | Linear                  | 1.0 M  | eval
# 1178 | text_encoder.text_model.encoder.layers.18.self_attn.v_proj          | Linear                  | 1.0 M  | eval
# 1179 | text_encoder.text_model.encoder.layers.18.self_attn.q_proj          | Linear                  | 1.0 M  | eval
# 1180 | text_encoder.text_model.encoder.layers.18.self_attn.out_proj        | Linear                  | 1.0 M  | eval
# 1181 | text_encoder.text_model.encoder.layers.18.layer_norm1               | LayerNorm               | 2.0 K  | eval
# 1182 | text_encoder.text_model.encoder.layers.18.mlp                       | CLIPMLP                 | 8.4 M  | eval
# 1183 | text_encoder.text_model.encoder.layers.18.mlp.activation_fn         | GELUActivation          | 0      | eval
# 1184 | text_encoder.text_model.encoder.layers.18.mlp.fc1                   | Linear                  | 4.2 M  | eval
# 1185 | text_encoder.text_model.encoder.layers.18.mlp.fc2                   | Linear                  | 4.2 M  | eval
# 1186 | text_encoder.text_model.encoder.layers.18.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1187 | text_encoder.text_model.encoder.layers.19                           | CLIPEncoderLayer        | 12.6 M | eval
# 1188 | text_encoder.text_model.encoder.layers.19.self_attn                 | CLIPAttention           | 4.2 M  | eval
# 1189 | text_encoder.text_model.encoder.layers.19.self_attn.k_proj          | Linear                  | 1.0 M  | eval
# 1190 | text_encoder.text_model.encoder.layers.19.self_attn.v_proj          | Linear                  | 1.0 M  | eval
# 1191 | text_encoder.text_model.encoder.layers.19.self_attn.q_proj          | Linear                  | 1.0 M  | eval
# 1192 | text_encoder.text_model.encoder.layers.19.self_attn.out_proj        | Linear                  | 1.0 M  | eval
# 1193 | text_encoder.text_model.encoder.layers.19.layer_norm1               | LayerNorm               | 2.0 K  | eval
# 1194 | text_encoder.text_model.encoder.layers.19.mlp                       | CLIPMLP                 | 8.4 M  | eval
# 1195 | text_encoder.text_model.encoder.layers.19.mlp.activation_fn         | GELUActivation          | 0      | eval
# 1196 | text_encoder.text_model.encoder.layers.19.mlp.fc1                   | Linear                  | 4.2 M  | eval
# 1197 | text_encoder.text_model.encoder.layers.19.mlp.fc2                   | Linear                  | 4.2 M  | eval
# 1198 | text_encoder.text_model.encoder.layers.19.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1199 | text_encoder.text_model.encoder.layers.20                           | CLIPEncoderLayer        | 12.6 M | eval
# 1200 | text_encoder.text_model.encoder.layers.20.self_attn                 | CLIPAttention           | 4.2 M  | eval
# 1201 | text_encoder.text_model.encoder.layers.20.self_attn.k_proj          | Linear                  | 1.0 M  | eval
# 1202 | text_encoder.text_model.encoder.layers.20.self_attn.v_proj          | Linear                  | 1.0 M  | eval
# 1203 | text_encoder.text_model.encoder.layers.20.self_attn.q_proj          | Linear                  | 1.0 M  | eval
# 1204 | text_encoder.text_model.encoder.layers.20.self_attn.out_proj        | Linear                  | 1.0 M  | eval
# 1205 | text_encoder.text_model.encoder.layers.20.layer_norm1               | LayerNorm               | 2.0 K  | eval
# 1206 | text_encoder.text_model.encoder.layers.20.mlp                       | CLIPMLP                 | 8.4 M  | eval
# 1207 | text_encoder.text_model.encoder.layers.20.mlp.activation_fn         | GELUActivation          | 0      | eval
# 1208 | text_encoder.text_model.encoder.layers.20.mlp.fc1                   | Linear                  | 4.2 M  | eval
# 1209 | text_encoder.text_model.encoder.layers.20.mlp.fc2                   | Linear                  | 4.2 M  | eval
# 1210 | text_encoder.text_model.encoder.layers.20.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1211 | text_encoder.text_model.encoder.layers.21                           | CLIPEncoderLayer        | 12.6 M | eval
# 1212 | text_encoder.text_model.encoder.layers.21.self_attn                 | CLIPAttention           | 4.2 M  | eval
# 1213 | text_encoder.text_model.encoder.layers.21.self_attn.k_proj          | Linear                  | 1.0 M  | eval
# 1214 | text_encoder.text_model.encoder.layers.21.self_attn.v_proj          | Linear                  | 1.0 M  | eval
# 1215 | text_encoder.text_model.encoder.layers.21.self_attn.q_proj          | Linear                  | 1.0 M  | eval
# 1216 | text_encoder.text_model.encoder.layers.21.self_attn.out_proj        | Linear                  | 1.0 M  | eval
# 1217 | text_encoder.text_model.encoder.layers.21.layer_norm1               | LayerNorm               | 2.0 K  | eval
# 1218 | text_encoder.text_model.encoder.layers.21.mlp                       | CLIPMLP                 | 8.4 M  | eval
# 1219 | text_encoder.text_model.encoder.layers.21.mlp.activation_fn         | GELUActivation          | 0      | eval
# 1220 | text_encoder.text_model.encoder.layers.21.mlp.fc1                   | Linear                  | 4.2 M  | eval
# 1221 | text_encoder.text_model.encoder.layers.21.mlp.fc2                   | Linear                  | 4.2 M  | eval
# 1222 | text_encoder.text_model.encoder.layers.21.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1223 | text_encoder.text_model.encoder.layers.22                           | CLIPEncoderLayer        | 12.6 M | eval
# 1224 | text_encoder.text_model.encoder.layers.22.self_attn                 | CLIPAttention           | 4.2 M  | eval
# 1225 | text_encoder.text_model.encoder.layers.22.self_attn.k_proj          | Linear                  | 1.0 M  | eval
# 1226 | text_encoder.text_model.encoder.layers.22.self_attn.v_proj          | Linear                  | 1.0 M  | eval
# 1227 | text_encoder.text_model.encoder.layers.22.self_attn.q_proj          | Linear                  | 1.0 M  | eval
# 1228 | text_encoder.text_model.encoder.layers.22.self_attn.out_proj        | Linear                  | 1.0 M  | eval
# 1229 | text_encoder.text_model.encoder.layers.22.layer_norm1               | LayerNorm               | 2.0 K  | eval
# 1230 | text_encoder.text_model.encoder.layers.22.mlp                       | CLIPMLP                 | 8.4 M  | eval
# 1231 | text_encoder.text_model.encoder.layers.22.mlp.activation_fn         | GELUActivation          | 0      | eval
# 1232 | text_encoder.text_model.encoder.layers.22.mlp.fc1                   | Linear                  | 4.2 M  | eval
# 1233 | text_encoder.text_model.encoder.layers.22.mlp.fc2                   | Linear                  | 4.2 M  | eval
# 1234 | text_encoder.text_model.encoder.layers.22.layer_norm2               | LayerNorm               | 2.0 K  | eval
# 1235 | text_encoder.text_model.final_layer_norm                            | LayerNorm               | 2.0 K  | eval
# --------------------------------------------------------------------------------------------------------------------------
# 1.3 B     Trainable params
# 0         Non-trainable params
# 1.3 B     Total params
# 5,159.810 Total estimated model params size (MB)
# 0         Modules in train mode
# 1236      Modules in eval mode

# %%
batch = SDTrainBatch(
    input_ids = torch.randint(0,100,[2,12]),
    images = torch.randn([2,3,128,128])
)
loss = module.training_step(batch,1)
# Out:
# torch.Size([2, 3, 128, 128]) torch.Size([2, 4, 16, 16]) torch.Size([2])
# /home/hieu/Workspace/projects/petorch/.venv/lib/python3.13/site-packages/lightning/pytorch/core/module.py:441: You are trying to `self.log()` but the `self.trainer` reference is not registered on the model yet. This is most likely because the model hasn't been passed to the `Trainer`

# %%
loss.shape
# Out:
# torch.Size([])
